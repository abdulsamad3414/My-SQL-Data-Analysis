# %% [markdown]
# # SQL PAYMENT AND CUSTOMER DATA ANALYSIS

# %%
import pandas as pd
# import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# import datset
df=pd.read_csv('D:\My SQL Data Analysis\payment.csv')
df.head()
# Out:
# <>:2: SyntaxWarning: invalid escape sequence '\M'
# <>:2: SyntaxWarning: invalid escape sequence '\M'
# C:\Users\Abdul-Samad\AppData\Local\Temp\ipykernel_12600\1910008062.py:2: SyntaxWarning: invalid escape sequence '\M'
#   df=pd.read_csv('D:\My SQL Data Analysis\payment.csv')
#    customerNumber checkNumber paymentDate    amount
# 0             103    HQ336336  2004-10-19   6066.78
# 1             103    JM555205  2003-06-05  14571.44
# 2             103    OM314933  2004-12-18   1676.14
# 3             112    BO864823  2004-12-17  14191.12
# 4             112     HQ55022  2003-06-06  32641.98

# %%
df.tail()
# Out:
#      customerNumber checkNumber paymentDate    amount
# 268             495    BH167026  2003-12-26  59265.14
# 269             495    FN155234  2004-05-14   6276.60
# 270             496    EU531600  2005-05-25  30253.75
# 271             496    MB342426  2003-07-16  32077.44
# 272             496     MN89921  2004-12-31  52166.00

# %%
df.shape
# Out:
# (273, 4)

# %%
sns.countplot(x='customerNumber',data=df)
# Out:
# <Axes: xlabel='customerNumber', ylabel='count'>

# %%
plt.hist(df['amount'])
# Out:
# (array([51., 53., 66., 54., 32.,  5.,  4.,  3.,  2.,  3.]),
#  array([   615.45 ,  12570.563,  24525.676,  36480.789,  48435.902,
#          60391.015,  72346.128,  84301.241,  96256.354, 108211.467,
#         120166.58 ]),
#  <BarContainer object of 10 artists>)

# %%
sns.boxplot(df['amount'])
# Out:
# <Axes: ylabel='amount'>

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 273 entries, 0 to 272
# Data columns (total 4 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   customerNumber  273 non-null    int64
#  1   checkNumber     273 non-null    object
#  2   paymentDate     273 non-null    object
#  3   amount          273 non-null    float64
# dtypes: float64(1), int64(1), object(2)
# memory usage: 8.7+ KB

# %%
df['paymentDate']=pd.to_datetime(df['paymentDate'])

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 273 entries, 0 to 272
# Data columns (total 4 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   customerNumber  273 non-null    int64
#  1   checkNumber     273 non-null    object
#  2   paymentDate     273 non-null    datetime64[ns]
#  3   amount          273 non-null    float64
# dtypes: datetime64[ns](1), float64(1), int64(1), object(1)
# memory usage: 8.7+ KB

# %%
df.describe()
# Out:
#        customerNumber                    paymentDate         amount
# count      273.000000                            273     273.000000
# mean       271.194139  2004-05-05 07:28:21.098901120   32431.645531
# min        103.000000            2003-01-16 00:00:00     615.450000
# 25%        161.000000            2003-11-18 00:00:00   16909.840000
# 50%        250.000000            2004-05-14 00:00:00   32077.440000
# 75%        363.000000            2004-11-17 00:00:00   45352.470000
# max        496.000000            2005-06-09 00:00:00  120166.580000
# std        120.069507                            NaN   20997.116917

# %%
# find the missing values 
df=df.isnull().sum()
df
# Out:
# customerNumber    0
# checkNumber       0
# paymentDate       0
# amount            0
# dtype: int64

# %%
# amount plot 
plt.figure(figsize=(10, 6))
plt.hist(df['amount'])
plt.show()

# %%
df["amount"] = df["amount"].round(0).astype(int)  # Converts to integer

# %%
df.info()
# Out:
# <class 'pandas.core.series.Series'>
# Index: 4 entries, customerNumber to amount
# Series name: None
# Non-Null Count  Dtype
# --------------  -----
# 4 non-null      int64
# dtypes: int64(1)
# memory usage: 236.0+ bytes

# %%
df.dtypes
# Out:
# dtype('int64')

# %%
df=pd.read_csv(r'D:\My SQL Data Analysis\fetch data from MYSQL.csv')
df.head()
# Out:
#         customerName       phone    city country   jobTitle paymentDate  \
# 0  Atelier graphique  40.32.2555  Nantes  France  Sales Rep  2004-10-19
# 1  Atelier graphique  40.32.2555  Nantes  France  Sales Rep  2004-10-19
# 2  Atelier graphique  40.32.2555  Nantes  France  Sales Rep  2004-10-19
# 3  Atelier graphique  40.32.2555  Nantes  France  Sales Rep  2004-10-19
# 4  Atelier graphique  40.32.2555  Nantes  France  Sales Rep  2004-10-19
#
#     amount      productName             productVendor  buyPrice  amount.1
# 0  6066.78  1982 Camaro Z28  Carousel DieCast Legends     46.53   6066.78
# 1  6066.78  1982 Camaro Z28  Carousel DieCast Legends     46.53   6066.78
# 2  6066.78  1982 Camaro Z28  Carousel DieCast Legends     46.53   6066.78
# 3  6066.78  1982 Camaro Z28  Carousel DieCast Legends     46.53   6066.78
# 4  6066.78  1982 Camaro Z28  Carousel DieCast Legends     46.53   6066.78

# %%
df.tail()
# Out:
#           customerName       phone    city country              jobTitle  \
# 995  Atelier graphique  40.32.2555  Nantes  France             President
# 996  Atelier graphique  40.32.2555  Nantes  France              VP Sales
# 997  Atelier graphique  40.32.2555  Nantes  France          VP Marketing
# 998  Atelier graphique  40.32.2555  Nantes  France  Sales Manager (APAC)
# 999  Atelier graphique  40.32.2555  Nantes  France   Sale Manager (EMEA)
#
#     paymentDate   amount                productName             productVendor  \
# 995  2004-10-19  6066.78  1966 Shelby Cobra 427 S/C  Carousel DieCast Legends
# 996  2004-10-19  6066.78  1966 Shelby Cobra 427 S/C  Carousel DieCast Legends
# 997  2004-10-19  6066.78  1966 Shelby Cobra 427 S/C  Carousel DieCast Legends
# 998  2004-10-19  6066.78  1966 Shelby Cobra 427 S/C  Carousel DieCast Legends
# 999  2004-10-19  6066.78  1966 Shelby Cobra 427 S/C  Carousel DieCast Legends
#
#      buyPrice  amount.1
# 995     29.18   6066.78
# ...

# %%
plt.figure(figsize=(30, 20))
sns.histplot(df['jobTitle'])
plt.show()

# %%
df.columns
# Out:
# Index(['customerName', 'phone', 'city', 'country', 'jobTitle', 'paymentDate',
#        'amount', 'productName', 'productVendor', 'buyPrice', 'amount.1'],
#       dtype='object')

# %%
df.isnull().sum(
    
)
# Out:
# customerName     0
# phone            0
# city             0
# country          0
# jobTitle         0
# paymentDate      0
# amount           0
# productName      0
# productVendor    0
# buyPrice         0
# amount.1         0
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 11 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   customerName   1000 non-null   object
#  1   phone          1000 non-null   object
#  2   city           1000 non-null   object
#  3   country        1000 non-null   object
#  4   jobTitle       1000 non-null   object
#  5   paymentDate    1000 non-null   object
#  6   amount         1000 non-null   float64
#  7   productName    1000 non-null   object
#  8   productVendor  1000 non-null   object
#  9   buyPrice       1000 non-null   float64
#  10  amount.1       1000 non-null   float64
# dtypes: float64(3), object(8)
# memory usage: 86.1+ KB

# %%
# drop columns
df.drop(columns=['amount.1'], inplace=True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 10 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   customerName   1000 non-null   object
#  1   phone          1000 non-null   object
#  2   city           1000 non-null   object
#  3   country        1000 non-null   object
#  4   jobTitle       1000 non-null   object
#  5   paymentDate    1000 non-null   object
#  6   amount         1000 non-null   float64
#  7   productName    1000 non-null   object
#  8   productVendor  1000 non-null   object
#  9   buyPrice       1000 non-null   float64
# dtypes: float64(2), object(8)
# memory usage: 78.3+ KB

# %%
df.describe()
# Out:
#         amount     buyPrice
# count  1000.00  1000.000000
# mean   6066.78    44.153600
# std       0.00    18.740362
# min    6066.78    15.910000
# 25%    6066.78    29.340000
# 50%    6066.78    38.580000
# 75%    6066.78    57.460000
# max    6066.78    98.300000

# %%
# duplicate recod
df=df.drop_duplicates()

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 307 entries, 0 to 999
# Data columns (total 10 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   customerName   307 non-null    object
#  1   phone          307 non-null    object
#  2   city           307 non-null    object
#  3   country        307 non-null    object
#  4   jobTitle       307 non-null    object
#  5   paymentDate    307 non-null    object
#  6   amount         307 non-null    float64
#  7   productName    307 non-null    object
#  8   productVendor  307 non-null    object
#  9   buyPrice       307 non-null    float64
# dtypes: float64(2), object(8)
# memory usage: 26.4+ KB

# %%
df['paymentDate']=pd.to_datetime(df['paymentDate'])

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 307 entries, 0 to 999
# Data columns (total 10 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   customerName   307 non-null    object
#  1   phone          307 non-null    object
#  2   city           307 non-null    object
#  3   country        307 non-null    object
#  4   jobTitle       307 non-null    object
#  5   paymentDate    307 non-null    datetime64[ns]
#  6   amount         307 non-null    float64
#  7   productName    307 non-null    object
#  8   productVendor  307 non-null    object
#  9   buyPrice       307 non-null    float64
# dtypes: datetime64[ns](1), float64(2), object(7)
# memory usage: 26.4+ KB

# %%
df['amount'] = df['amount'].round(0).astype(int)
df['buyPrice'] = df['buyPrice'].round(0).astype(int)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 307 entries, 0 to 999
# Data columns (total 10 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   customerName   307 non-null    object
#  1   phone          307 non-null    object
#  2   city           307 non-null    object
#  3   country        307 non-null    object
#  4   jobTitle       307 non-null    object
#  5   paymentDate    307 non-null    datetime64[ns]
#  6   amount         307 non-null    int64
#  7   productName    307 non-null    object
#  8   productVendor  307 non-null    object
#  9   buyPrice       307 non-null    int64
# dtypes: datetime64[ns](1), int64(2), object(7)
# memory usage: 26.4+ KB

# %%
df.rename(columns={'amount': 'Total_Amount'}, inplace=True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 307 entries, 0 to 999
# Data columns (total 10 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   customerName   307 non-null    object
#  1   phone          307 non-null    object
#  2   city           307 non-null    object
#  3   country        307 non-null    object
#  4   jobTitle       307 non-null    object
#  5   paymentDate    307 non-null    datetime64[ns]
#  6   Total_Amount   307 non-null    int64
#  7   productName    307 non-null    object
#  8   productVendor  307 non-null    object
#  9   buyPrice       307 non-null    int64
# dtypes: datetime64[ns](1), int64(2), object(7)
# memory usage: 26.4+ KB

# %%
Total_Revenue=df['Total_Amount'].sum()
Total_Revenue
# Out:
# np.int64(1862569)

# %%
Avg_payment=df['Total_Amount'].mean()
Avg_payment
# Out:
# np.float64(6067.0)

# %%
Unique_customer=df['customerName'].nunique()
Unique_customer
# Out:
# 1

# %%
# top 5 customer by payment
Top_Customer=df.groupby('customerName')['Total_Amount'].sum().sort_values(ascending=False).head(5)
Top_Customer
# Out:
# customerName
# Atelier graphique    1862569
# Name: Total_Amount, dtype: int64

# %%
# Top product 
Top_product=df['productName'].value_counts().head(5)
Top_product
# Out:
# productName
# The USS Constitution Ship         7
# HMS Bounty                        7
# America West Airlines B757-200    7
# The Mayflower                     7
# American Airlines: B767-300       7
# Name: count, dtype: int64

# %%
# Contry based analysis 
Contry_based=df.groupby('country')['Total_Amount'].sum().sort_values(ascending=False)
Contry_based
# Out:
# country
# France    1862569
# Name: Total_Amount, dtype: int64

# %%
df.columns
# Out:
# Index(['customerName', 'phone', 'city', 'country', 'jobTitle', 'paymentDate',
#        'Total_Amount', 'productName', 'productVendor', 'buyPrice'],
#       dtype='object')

# %%
sns.barplot(x='city',y='Total_Amount',data=df)
# Out:
# <Axes: xlabel='city', ylabel='Total_Amount'>

# %%
sns.histplot(df['Total_Amount'])
# Out:
# <Axes: xlabel='Total_Amount', ylabel='Count'>

# %%
sns.scatterplot(x='Total_Amount',y='buyPrice',data=df)
# Out:
# <Axes: xlabel='Total_Amount', ylabel='buyPrice'>

# %%
sns.violinplot(x='Total_Amount',data=df,y='customerName')
# Out:
# <Axes: xlabel='Total_Amount', ylabel='customerName'>
